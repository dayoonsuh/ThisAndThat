# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request

# %%
import re

# %%
url = "https://www.chicagomag.com/chicago-magazine/january-2023/our-30-favorite-things-to-eat-right-now/"
req = Request(url, headers={'User-Agent':'Chrome/66.0.3359.181'})
web = urlopen(req).read()
soup = BeautifulSoup(web,'html.parser')

# %%
article = soup.find('div', 'article-body')

# %%
menu = [m.get_text() for m in article.find_all('h2')]
price = []
restaurant = [r.get_text()[3:] for r in article.find_all('h3')]
address = []

# %%
descriptions = article.find_all('p')

# %%
pattern_price = re.compile('\$[\d\.]+')
pattern_adr = re.compile("\d+ [NEWS]+. [\w\s.,]*\w")

for description in descriptions:
    price_and_adr = description.find('em').get_text()
    p = re.findall(pattern_price, price_and_adr)
    if len(p) == 1:
        price.append(p[0])
    elif len(p) > 1:
        price.append(p[-1])
    else:
        price.append(None)
    
    adr = re.findall(pattern_adr, price_and_adr)
    address.append(adr[0] if len(adr) == 1 else None )

# %%
print(len(menu), len(price), len(restaurant), len(address))
# Out:
# 30 30 30 30

# %%
import pandas as pd

# %%
data = {'Menu': menu, 'Price':price, 'Restaurant': restaurant, 'Location': address}
thirtyplaces = pd.DataFrame(data)

# %%
thirtyplaces.head()
# Out:
#                                     Menu   Price         Restaurant  \
# 0                        Yaki Beef Gyoza  $7.95.     Monster Ramen
# 1  Dark Chocolate and Pecan Banana Bread     $5.    Mindy’s Bakery
# 2                        Chicken Diavola    $26.      Coda di Volpe
# 3                  Purple Velvet Cupcake  $5.50.  Jennivee’s Bakery
# 4                 Charred Broccoli Salad    None         Split-Rail
#
#                                Location
# 0  3435 W. Fullerton Ave., Logan Square
# 1      1623 N. Milwaukee Ave., Bucktown
# 2     3335 N. Southport Ave., Lake View
# 3     3301 N. Sheffield Ave., Lake View
# 4   2500 W. Chicago Ave., Humboldt Park

# %%
import folium
import googlemaps
import numpy as np

# %%
from tqdm import tqdm_notebook

# %%
key = "Your Key"
gmaps = googlemaps.Client(key=key)

# %%
lat = []
lng = []

for n in tqdm_notebook(thirtyplaces.index):
    if thirtyplaces['Location'][n] != None:
        target = thirtyplaces['Location'][n]+', '+'Chicago'
        gmaps_output = gmaps.geocode(target)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# C:\Users\dayoo\AppData\Local\Temp\ipykernel_2352\3032199049.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(thirtyplaces.index):
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
thirtyplaces.to_csv('30_things_to_eat_in_chicago_jan23.csv', sep = ',', encoding = 'UTF-8')

# %%
thirtyplaces['lat'] = lat
thirtyplaces['lng'] = lng

# %%
mapping = folium.Map(location = [thirtyplaces['lat'].mean(), thirtyplaces['lng'].mean()], zoom_start = 11)

# %%
for n in thirtyplaces.index:
    if thirtyplaces['Location'][n] != None:
        folium.Marker([thirtyplaces['lat'][n], thirtyplaces['lng'][n]], popup=thirtyplaces['Restaurant'][n]).add_to(mapping)

# %%
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcdfe5803092608b185b458435fd7d5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcdfe5803092608b185b458435fd7d5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_dcdfe5803092608b185b458435fd7d5f = L.map(
#                 &quot;map_dcdfe5803092608b185b458435fd7d5f&quot;,
#                 {
#                     center: [41.897761193103456, -87.68464390689654],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a099d45dfdd536c93465700d18bf2404 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#             var marker_a51adbe77da3b2d880da55ff563aa610 = L.marker(
#                 [41.9244376, -87.7135253],
#                 {}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#         var popup_16682556408f3a92e5d0b083d0eb8e0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ad9f9786959c25467bd1f48bcb2da6f = $(`&lt;div id=&quot;html_3ad9f9786959c25467bd1f48bcb2da6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Monster Ramen &lt;/div&gt;`)[0];
#             popup_16682556408f3a92e5d0b083d0eb8e0a.setContent(html_3ad9f9786959c25467bd1f48bcb2da6f);
#
#
#         marker_a51adbe77da3b2d880da55ff563aa610.bindPopup(popup_16682556408f3a92e5d0b083d0eb8e0a)
#         ;
#
#
#
#
#             var marker_72021b13bf6b2d39f5cc0702ab7f8fcf = L.marker(
#                 [41.9110653, -87.67807909999999],
#                 {}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#         var popup_a30ca433bf77da66d3bfc36905bec769 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_64c8c7feb28ad4708290267d5e208a7f = $(`&lt;div id=&quot;html_64c8c7feb28ad4708290267d5e208a7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mindy’s Bakery &lt;/div&gt;`)[0];
#             popup_a30ca433bf77da66d3bfc36905bec769.setContent(html_64c8c7feb28ad4708290267d5e208a7f);
#
#
#         marker_72021b13bf6b2d39f5cc0702ab7f8fcf.bindPopup(popup_a30ca433bf77da66d3bfc36905bec769)
#         ;
#
#
#
#
#             var marker_9be27e21915e1274b5f08d2de3998ebb = L.marker(
#                 [41.9426411, -87.66362559999999],
#                 {}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#         var popup_58762c80200dabb34cad8d463e89803f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_caa9b5e04e370a797d6819baec358b7b = $(`&lt;div id=&quot;html_caa9b5e04e370a797d6819baec358b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coda di Volpe&lt;/div&gt;`)[0];
#             popup_58762c80200dabb34cad8d463e89803f.setContent(html_caa9b5e04e370a797d6819baec358b7b);
#
#
#         marker_9be27e21915e1274b5f08d2de3998ebb.bindPopup(popup_58762c80200dabb34cad8d463e89803f)
#         ;
#
#
#
#
#             var marker_f756b3c3e069d912d866e0033e47ee4f = L.marker(
#                 [41.9419112, -87.65382],
#                 {}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#         var popup_a5551dcc20f384166608f898061c2f41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bd5deac044db6c5fee60664b3f238260 = $(`&lt;div id=&quot;html_bd5deac044db6c5fee60664b3f238260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jennivee’s Bakery&lt;/div&gt;`)[0];
#             popup_a5551dcc20f384166608f898061c2f41.setContent(html_bd5deac044db6c5fee60664b3f238260);
#
#
#         marker_f756b3c3e069d912d866e0033e47ee4f.bindPopup(popup_a5551dcc20f384166608f898061c2f41)
#         ;
#
#
#
#
#             var marker_5eea256a6d1e17d2c9009200f12aaebf = L.marker(
#                 [41.8959053, -87.6895897],
#                 {}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#         var popup_5f30cd730d5ccc264d0f8acfbfb01c44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8c11ebb570b224f780b349398e245bb6 = $(`&lt;div id=&quot;html_8c11ebb570b224f780b349398e245bb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Split-Rail&lt;/div&gt;`)[0];
#             popup_5f30cd730d5ccc264d0f8acfbfb01c44.setContent(html_8c11ebb570b224f780b349398e245bb6);
#
#
#         marker_5eea256a6d1e17d2c9009200f12aaebf.bindPopup(popup_5f30cd730d5ccc264d0f8acfbfb01c44)
#         ;
#
#
#
#
#             var marker_c0227eb407561ce7bc79556585899aa0 = L.marker(
#                 [41.89984159999999, -87.6874886],
#                 {}
#             ).addTo(map_dcdfe5803092608b185b458435fd7d5f);
#
#
#         var popup_d05d878513c854d1909ab01cbd07bced = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e7cd47144aa42f28a1daaa3ab04942e = $(`
